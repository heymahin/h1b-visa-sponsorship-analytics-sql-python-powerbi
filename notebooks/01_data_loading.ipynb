# %% [markdown]
# # H1B Visa Data Understanding

# %% [markdown]
# ## Step 1 — Load Raw Data & Import Libraries
# ### Why?
# The four quarterly FY2024 H1B LCA disclosure Excel files are stored inside the project folder. We import the required libraries and load these files into Pandas DataFrames so they can be cleaned, transformed, and analyzed in later steps.

# %%
import pandas as pd

# %% [markdown]
# ## Step 2 — Read the Quarterly Excel Files
# ### Why?
# Each file contains one quarter of FY2024 H1B LCA data. Loading all four files allows us to inspect their structure and later combine them into one master dataset.

# %%
q1 = pd.read_excel("../data/raw/LCA_Disclosure_Data_FY2024_Q1.xlsx")
q2 = pd.read_excel("../data/raw/LCA_Disclosure_Data_FY2024_Q2.xlsx")
q3 = pd.read_excel("../data/raw/LCA_Disclosure_Data_FY2024_Q3.xlsx")
q4 = pd.read_excel("../data/raw/LCA_Disclosure_Data_FY2024_Q4.xlsx")

# %% [markdown]
# ## Step 3 — Check Dataset Size
# ### Why?
# We check the number of rows and columns in each quarter to understand data volume and verify that all files loaded successfully.

# %%
print("Q1 Shape:", q1.shape)
print("Q2 Shape:", q2.shape)
print("Q3 Shape:", q3.shape)
print("Q4 Shape:", q4.shape)
# Out:
# Q1 Shape: (99692, 97)
# Q2 Shape: (123978, 97)
# Q3 Shape: (216470, 97)
# Q4 Shape: (120897, 97)

# %% [markdown]
# ## Step 4 — Inspect Column Names
# ### Why?
# The raw files contain many columns. We inspect column names to identify the most relevant fields for business analysis and H1B insights.

# %%
q1.columns.tolist()
# Out:
# ['CASE_NUMBER',
#  'CASE_STATUS',
#  'RECEIVED_DATE',
#  'DECISION_DATE',
#  'ORIGINAL_CERT_DATE',
#  'VISA_CLASS',
#  'JOB_TITLE',
#  'SOC_CODE',
#  'SOC_TITLE',
#  'FULL_TIME_POSITION',
#  'BEGIN_DATE',
#  'END_DATE',
#  'TOTAL_WORKER_POSITIONS',
#  'NEW_EMPLOYMENT',
#  'CONTINUED_EMPLOYMENT',
#  'CHANGE_PREVIOUS_EMPLOYMENT',
#  'NEW_CONCURRENT_EMPLOYMENT',
#  'CHANGE_EMPLOYER',
#  'AMENDED_PETITION',
#  'EMPLOYER_NAME',
#  'TRADE_NAME_DBA',
#  'EMPLOYER_ADDRESS1',
#  'EMPLOYER_ADDRESS2',
#  'EMPLOYER_CITY',
#  'EMPLOYER_STATE',
#  'EMPLOYER_POSTAL_CODE',
#  'EMPLOYER_COUNTRY',
#  'EMPLOYER_PROVINCE',
#  'EMPLOYER_PHONE',
#  'EMPLOYER_PHONE_EXT',
#  'EMPLOYER_FEIN',
#  'NAICS_CODE',
#  'EMPLOYER_POC_LAST_NAME',
#  'EMPLOYER_POC_FIRST_NAME',
#  'EMPLOYER_POC_MIDDLE_NAME',
#  'EMPLOYER_POC_JOB_TITLE',
#  'EMPLOYER_POC_ADDRESS1',
#  'EMPLOYER_POC_ADDRESS2',
#  'EMPLOYER_POC_CITY',
#  'EMPLOYER_POC_STATE',
#  'EMPLOYER_POC_POSTAL_CODE',
#  'EMPLOYER_POC_COUNTRY',
# ...

# %% [markdown]
# ## Step 5 — Preview the Data
# ### Why?
# Viewing the first few rows helps us understand the data format, missing values, and the type of information available in each column.

# %%
q1.head()
# Out:
#           CASE_NUMBER            CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0  I-200-23080-866996  Certified - Withdrawn    2023-03-21    2023-12-31
# 1  I-200-23364-599927              Withdrawn    2023-12-30    2023-12-30
# 2  I-203-23355-583713              Certified    2023-12-21    2023-12-29
# 3  I-200-23355-584372              Certified    2023-12-21    2023-12-29
# 4  I-200-23355-585364              Certified    2023-12-21    2023-12-29
#
#   ORIGINAL_CERT_DATE      VISA_CLASS  \
# 0         2023-03-28            H-1B
# 1                NaT            H-1B
# 2                NaT  E-3 Australian
# 3                NaT            H-1B
# 4                NaT            H-1B
#
#                                   JOB_TITLE    SOC_CODE  \
# 0            Biochemical Research Associate  19-1021.00
# 1            Sr. Mechanical Design Engineer  17-2141.00
# 2                  Infrastructure  Engineer  15-1244.00
# 3  Database Administrators - Kbgfjg204319-5  15-1242.00
# ...

# %%
# Out:
# Access is denied.
